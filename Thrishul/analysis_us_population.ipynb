# %% [markdown]
# # US Population Analysis (2010-2024)
# This notebook contains the dataset and charts.

# %%
import pandas as pd
df = pd.read_csv('us_population_2010_2024.csv')
df

# %% [markdown]
# Charts saved as PNG files alongside this notebook.
